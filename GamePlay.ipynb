# %%
import tetrisplay

# %%
grid = tetrisplay.build_clean_grid()

# %%
tetrisplay.display_grid(grid)
# Out:
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |

# %%
grid = tetrisplay.drop_block(grid, 3)
tetrisplay.display_grid(grid)
# Out:
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |  |  |
# |  |  |  |██|  |

# %%
## from tetrisplay import *   # be careful: names are overwritten.

# %%
grid = build_clean_grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 grid = build_clean_grid()
#
# NameError: name 'build_clean_grid' is not defined

# %%
grid = drop_block(grid, 2)
display_grid(grid)

# %%
import tetrisplay
import random

grid = tetrisplay.build_clean_grid()

for i in range(15):
    grid = tetrisplay.drop_block(grid, random.randint(0, tetrisplay._COLUMNS-1))
    tetrisplay.display_grid(grid)

# %% [markdown]
# ## Start here...

# %%
import tetrisplay
import random
import time

from IPython.display import clear_output

grid = tetrisplay.build_clean_grid()

"""
for i in range(15):
    grid = tetrisplay.drop_block(grid, random.randint(0, tetrisplay._COLUMNS-1))
    tetrisplay.display_grid(grid)
    time.sleep(0.3)
    clear_output(wait=True)
"""

# %% [raw]
# _INTERVAL = 0.3
#
#
# def show_dropping_block(grid, column_number):
#     """Given a grid and a column to drop into, simulate a visual drop of a box."""
#
#     for row in range(tetrisplay._ROWS):
#         grid[column_number][row] = tetrisplay._BLOCK
#         tetrisplay.display_grid(grid)
#         time.sleep(_INTERVAL)
#         clear_output(wait=True)
#         grid[column_number][row] = tetrisplay._BLANK
#         tetrisplay.display_grid(grid)
#         time.sleep(_INTERVAL)
#         clear_output(wait=True)

# %%
## grid = tetrisplay.build_clean_grid()
tetrisplay.display_grid(grid)

# %%
tetrisplay.show_dropping_block(grid, 2)

# %% [markdown]
# ### Adjust show_dropping_block to stop when it hits the bottom or just above an existing block.
# ### Work out how to determine if the user has pressed the <- or -> key.
# ### If an arrow key is pressed, move the block.
# ### When the block stops... check for entire row of filled blocks.
# ### Drop the next block.

# %% [raw]
# create the empty grid
#
# while True:
#     randomly drop a block (assuming the randomly selected column has room)
#     time.sleep(0.1) five times and in between sleeps do this:
#     OR use Kevin's idea of the TIMEDELTA in a tight loop:
#         check for a key-press:
#             if ->: move the block one column to the right (if possible)
#             if <-: move the block one columns to the left (if possible)
#             Q. what do we do about the time.sleep delay?!?

# %%
import time

# %%
input("Tell me your name:")

# %%
import keyboard   # not installed yet (so this will initially fail).
